# %%
#Variables

name = "Zishan"
age = 23
marks = 95.5
is_passed = True

print(name)
print(age)
print(marks)
print(is_passed)
# Out:
# Zishan
# 23
# 95.5
# True

# %%
#Lists

marks = [95, 87, 7, 68, 91]

print(marks)
print(marks[0])
print(marks[2])
print(len(marks))
# Out:
# [95, 87, 7, 68, 91]
# 95
# 7
# 5

# %%
#Loops

marks = [95, 87, 7, 8, 92]

for mark in marks:
  print(mark)
# Out:
# 95
# 87
# 7
# 8
# 92

# %%
#Functions

def greet_student(name):
  print("Hello " + name + "! Welcome to Atrangi AI.")

greet_student("Zishan")
greet_student("Rahul")
greet_student("Avinash")
# Out:
# Hello Zishan! Welcome to Atrangi AI.
# Hello Rahul! Welcome to Atrangi AI.
# Hello Avinash! Welcome to Atrangi AI.

# %%
#Dictionaries

student = {
    "name": "Zishan",
    "marks": 87,
    "passed": True
}

print(student["name"])
print(student["marks"])
print(student["passed"])
# Out:
# Zishan
# 87
# True

# %%
model_params = {
    "max_depth": 3,
    "learning_rate": 0.01,
    "n_estimators": 100
}

print(model_params)
# Out:
# {'max_depth': 3, 'learning_rate': 0.01, 'n_estimators': 100}

# %%
#Variables

student_name = "Zishan"
student_marks = 87.5
is_passed = True

#Lists

all_marks = [95, 87, 72, 68, 91]

#Loops

for mark in all_marks:
  print(mark)

#Functions

def check_pass(marks):
  if marks >= 40:
    print("Pass")
  else:
    print("Fail")

check_pass(87)
check_pass(33)

#Dictionaries

student_info = {
    "name": "Zishan",
    "marks": 87.5,
    "passed": True
}

print(student_info["name"])
# Out:
# 95
# 87
# 72
# 68
# 91
# Pass
# Fail
# Zishan
